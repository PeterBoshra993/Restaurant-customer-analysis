# %% [markdown]
# Apply what you have learned from pandas to make a simple EDA on restaurant dataset.

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("restaurant.csv")

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    object
#  3   smoker      244 non-null    object
#  4   day         244 non-null    object
#  5   time        244 non-null    object
#  6   size        244 non-null    int64
# dtypes: float64(2), int64(1), object(4)
# memory usage: 13.5+ KB

# %%
df.describe()
# Out:
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000

# %%
df.corr()
# Out:
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %%
import seaborn as sns
sns.scatterplot(x='sex',y='total_bill',color='r',data=df)
# Out:
# <AxesSubplot:xlabel='sex', ylabel='total_bill'>

# %% [markdown]
# From the first graph it seems that Males are paying the most than females. And females has the least paying value

# %%
sns.scatterplot(x='smoker',y='total_bill',color='b',data=df)
# Out:
# <AxesSubplot:xlabel='smoker', ylabel='total_bill'>

# %% [markdown]
# That will mean nothing for me because the smokers baying the least and most values that will only mean your restaurant are accepting least paying female that smokes and male that smokes

# %%
sns.jointplot(data = df, x = "total_bill", y = "tip", hue = "sex", palette = "rocket")

# %%
sns.pairplot(df)

# %%
df["tip"].value_counts().median()
# Out:
# 1.0

# %%
df["tip"].value_counts().mean()
# Out:
# 1.983739837398374

# %%
df["tip"].value_counts()
# Out:
# 2.00    33
# 3.00    23
# 4.00    12
# 5.00    10
# 2.50    10
#         ..
# 4.34     1
# 1.56     1
# 5.20     1
# 2.60     1
# 1.75     1
# Name: tip, Length: 123, dtype: int64

# %%
df["sex"].value_counts()
# Out:
# Male      157
# Female     87
# Name: sex, dtype: int64

# %%
di_4 = {"Male":1, "Female":0}
df.replace({"sex": di_4}, inplace = True)

# %%
df["smoker"].value_counts()
# Out:
# No     151
# Yes     93
# Name: smoker, dtype: int64

# %%
di_1 = {"Yes":1, "No":0}
df.replace({"smoker": di_1}, inplace = True)

# %%
df["day"].value_counts()
# Out:
# Sat     87
# Sun     76
# Thur    62
# Fri     19
# Name: day, dtype: int64

# %%
di_2 = {"Sat":1, "Sun":2, "Thur":3, "Fri":4}
df.replace({"day": di_2}, inplace = True)

# %%
df["time"].value_counts()
# Out:
# Dinner    176
# Lunch      68
# Name: time, dtype: int64

# %%
di_2 = {"Dinner":0, "Lunch":1}
df.replace({"time": di_2}, inplace = True)

# %%
df["size"].value_counts()
# Out:
# 2    156
# 3     38
# 4     37
# 5      5
# 1      4
# 6      4
# Name: size, dtype: int64

# %%
sns.pairplot(df, 
                 markers="+",
                 diag_kind="kde",
                 kind='reg',
                 plot_kws={'line_kws':{'color':'#aec6cf'}, 
                           'scatter_kws': {'alpha': 0.7, 
                                           'color': 'red'}},
                 corner=True);

# %%
df.groupby("sex").describe().transpose()
# Out:
# sex                       0           1
# total_bill count  87.000000  157.000000
#            mean   18.056897   20.744076
#            std     8.009209    9.246469
#            min     3.070000    7.250000
#            25%    12.750000   14.000000
#            50%    16.400000   18.350000
#            75%    21.520000   24.710000
#            max    44.300000   50.810000
# tip        count  87.000000  157.000000
#            mean    2.833448    3.089618
#            std     1.159495    1.489102
#            min     1.000000    1.000000
#            25%     2.000000    2.000000
#            50%     2.750000    3.000000
#            75%     3.500000    3.760000
#            max     6.500000   10.000000
# smoker     count  87.000000  157.000000
#            mean    0.379310    0.382166
#            std     0.488028    0.487472
#            min     0.000000    0.000000
#            25%     0.000000    0.000000
#            50%     0.000000    0.000000
# ...

# %% [markdown]
# Now let's try to remove outliers from our dataframe

# %%
def subset_by_iqr(df, column, whisker_width=1.5):
    """
    description:
        Remove outliers from a dataframe by column, including optional 
        whiskers, removing rows for which the column value are 
        less than Q1-1.5IQR or greater than Q3+1.5IQR.
    Arguments:
        df (`:obj:pd.DataFrame`): A pandas dataframe to subset
        column (str): Name of the column to calculate the subset from.
        whisker_width (float): Optional, loosen the IQR filter by a
                               factor of `whisker_width` * IQR.
    Returns:
        (`:obj:pd.DataFrame`): Filtered dataframe
    """
    # Calculate Q1, Q2 and IQR
    q1 = df["total_bill"].quantile(0.25)                 
    q3 = df["total_bill"].quantile(0.75)
    iqr = q3 - q1
    # Apply filter with respect to IQR, including optional whiskers
    filter = (df["total_bill"] >= q1 - whisker_width*iqr) & (df["total_bill"] <= q3 + whisker_width*iqr)
    return df.loc[filter]

# %%
# Example for whiskers = 1.5, as requested by the OP
df_filtered = subset_by_iqr(df, "total_bill", whisker_width=1.5)

# %%
df_filtered.head()
# Out:
#    total_bill   tip  sex  smoker  day  time  size
# 0       16.99  1.01    0       0    2     0     2
# 1       10.34  1.66    1       0    2     0     3
# 2       21.01  3.50    1       0    2     0     3
# 3       23.68  3.31    1       0    2     0     2
# 4       24.59  3.61    0       0    2     0     4

# %%
df_filtered.describe()
# Out:
#        total_bill         tip         sex      smoker         day        time  \
# count  235.000000  235.000000  235.000000  235.000000  235.000000  235.000000
# mean    18.798681    2.901489    0.638298    0.374468    2.063830    0.280851
# std      7.438468    1.225651    0.481519    0.485018    0.965301    0.450374
# min      3.070000    1.000000    0.000000    0.000000    1.000000    0.000000
# 25%     13.215000    2.000000    0.000000    0.000000    1.000000    0.000000
# 50%     17.460000    2.750000    1.000000    0.000000    2.000000    0.000000
# 75%     23.135000    3.500000    1.000000    1.000000    3.000000    1.000000
# max     40.170000    7.580000    1.000000    1.000000    4.000000    1.000000
#
#              size
# count  235.000000
# mean     2.523404
# std      0.911984
# min      1.000000
# 25%      2.000000
# 50%      2.000000
# 75%      3.000000
# max      6.000000

# %%
sns.pairplot(df_filtered, 
                 diag_kind="kde",
                 kind='reg',
                 plot_kws={'line_kws':{'color':'#aec6cf'}, 
                           'scatter_kws': {'alpha': 0.7, 
                                           'color': 'blue'}},
                 corner=True);
